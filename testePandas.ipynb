# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabrielhfalcao/estudos_Pandas/blob/main/testePandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Credit.csv', delimiter=',')

df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df[['duration']]
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
df.loc[1:5]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
# 5   'no checking'        36                   'existing paid'
#
#                purpose  credit_amount      savings_status employment  \
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
# 5            education           9055  'no known savings'     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# ...

# %%
df.loc[[1, 5]]
# Out:
#   checking_status  duration   credit_history    purpose  credit_amount  \
# 1        0<=X<200        48  'existing paid'   radio/tv           5951
# 5   'no checking'        36  'existing paid'  education           9055
#
#        savings_status employment  installment_commitment  \
# 1                <100     1<=X<4                       2
# 5  'no known savings'     1<=X<4                       2
#
#         personal_status other_parties  ...   property_magnitude age  \
# 1  'female div/dep/mar'          none  ...        'real estate'  22
# 5         'male single'          none  ...  'no known property'  35
#
#    other_payment_plans     housing existing_credits                   job  \
# 1                 none         own                1               skilled
# 5                 none  'for free'                1  'unskilled resident'
#
#   num_dependents  own_telephone foreign_worker class
# 1              1           none            yes   bad
# ...

# %%
df.loc[df['purpose'] == 'radio/tv']
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
df.loc[df['credit_amount'] > 18000]
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
consulta1 = df[['checking_status', 'duration']].loc[df['credit_amount'] > 18000]
consulta1
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
serie1 = pd.Series([1, 3, 4, 4, 5])
serie1
# Out:
# 0    1
# 1    3
# 2    4
# 3    4
# 4    5
# dtype: int64

# %%
import numpy as np

array1 = np.array([0, 1, 2, 4])
serie2 = pd.Series(array1)
serie2
# Out:
# 0    0
# 1    1
# 2    2
# 3    4
# dtype: int64

# %%
serie3 = df['purpose']
type(serie3)
# Out:
# pandas.core.series.Series

# %%
serie4 = df[['purpose']]
type(serie4)
# Out:
# pandas.core.frame.DataFrame

# %%
df.rename(columns={'purpose': 'Purpose'})
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  Purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
df
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                  purpose  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %% [markdown]
# ##Para fazer a alteração Definitivamente

# %%
df.rename(columns={'purpose': 'propósito'}, inplace=True)
# Out:
#     checking_status  duration                    credit_history  \
# 0                <0         6  'critical/other existing credit'
# 1          0<=X<200        48                   'existing paid'
# 2     'no checking'        12  'critical/other existing credit'
# 3                <0        42                   'existing paid'
# 4                <0        24              'delayed previously'
# ..              ...       ...                               ...
# 995   'no checking'        12                   'existing paid'
# 996              <0        30                   'existing paid'
# 997   'no checking'        12                   'existing paid'
# 998              <0        45                   'existing paid'
# 999        0<=X<200        45  'critical/other existing credit'
#
#                propósito  credit_amount      savings_status  employment  \
# 0               radio/tv           1169  'no known savings'         >=7
# ...

# %%
df.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#              propósito  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
df.head()
# Out:
#                      credit_history            propósito  credit_amount  \
# 0  'critical/other existing credit'             radio/tv           1169
# 1                   'existing paid'             radio/tv           5951
# 2  'critical/other existing credit'            education           2096
# 3                   'existing paid'  furniture/equipment           7882
# 4              'delayed previously'            'new car'           4870
#
#        savings_status employment  installment_commitment  \
# 0  'no known savings'        >=7                       4
# 1                <100     1<=X<4                       2
# 2                <100     4<=X<7                       2
# 3                <100     4<=X<7                       2
# 4                <100     1<=X<4                       3
#
#         personal_status other_parties  residence_since   property_magnitude  \
# 0         'male single'          none                4        'real estate'
# ...

# %%
df.isnull()
# Out:
#      credit_history  propósito  credit_amount  savings_status  employment  \
# 0             False      False          False           False       False
# 1             False      False          False           False       False
# 2             False      False          False           False       False
# 3             False      False          False           False       False
# 4             False      False          False           False       False
# ..              ...        ...            ...             ...         ...
# 995           False      False          False           False       False
# 996           False      False          False           False       False
# 997           False      False          False           False       False
# 998           False      False          False           False       False
# 999           False      False          False           False       False
#
#      installment_commitment  personal_status  other_parties  residence_since  \
# ...

# %%
df.isnull().sum()
# Out:
# credit_history            0
# propósito                 0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# job                       0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
df.dropna()
# Out:
#                        credit_history            propósito  credit_amount  \
# 0    'critical/other existing credit'             radio/tv           1169
# 1                     'existing paid'             radio/tv           5951
# 2    'critical/other existing credit'            education           2096
# 3                     'existing paid'  furniture/equipment           7882
# 4                'delayed previously'            'new car'           4870
# ..                                ...                  ...            ...
# 995                   'existing paid'  furniture/equipment           1736
# 996                   'existing paid'           'used car'           3857
# 997                   'existing paid'             radio/tv            804
# 998                   'existing paid'             radio/tv           1845
# 999  'critical/other existing credit'           'used car'           4576
#
#          savings_status  employment  installment_commitment  \
# ...

# %%
df['credit_history'].fillna(0, inplace=True)

# %%
df.loc[df['credit_history'] == 0]
# Out:
# Empty DataFrame
# Columns: [credit_history, propósito, credit_amount, savings_status, employment, installment_commitment, personal_status, other_parties, residence_since, property_magnitude, age, other_payment_plans, housing, existing_credits, job, num_dependents, own_telephone, foreign_worker, class]
# Index: []

# %%
df.iloc[0:,0:5]
# Out:
#                        credit_history            propósito  credit_amount  \
# 0    'critical/other existing credit'             radio/tv           1169
# 1                     'existing paid'             radio/tv           5951
# 2    'critical/other existing credit'            education           2096
# 3                     'existing paid'  furniture/equipment           7882
# 4                'delayed previously'            'new car'           4870
# ..                                ...                  ...            ...
# 995                   'existing paid'  furniture/equipment           1736
# 996                   'existing paid'           'used car'           3857
# 997                   'existing paid'             radio/tv            804
# 998                   'existing paid'             radio/tv           1845
# 999  'critical/other existing credit'           'used car'           4576
#
#          savings_status  employment
# 0    'no known savings'         >=7
# ...
